# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread("C:\\opencv\\sources\\samples\\data\\box.png")
plt.imshow(img), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1b729808>, None)

# %%
orb = cv.ORB_create()

# %%
kp = orb.detect(img, None)

# %%
kp, des = orb.compute(img, kp)
img2 = cv.drawKeypoints(img, kp, None, color=(0, 255, 0), flags =0)
plt.imshow(img2), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1fb640b8>, None)
